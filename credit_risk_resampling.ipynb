# %% [markdown]
# # Credit Risk Resampling Techniques

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np
import pandas as pd
from pathlib import Path
from collections import Counter
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/0s/9pgh43n143n123rjw56tynrr0000gn/T/ipykernel_5435/88127112.py in <module>
#       3 from pathlib import Path
#       4 from collections import Counter
# ----> 5 import imblearn
#
# ModuleNotFoundError: No module named 'imblearn'

# %%
conda create -n imblearn python=3.8
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.11.0
#   latest version: 4.13.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /opt/anaconda3/envs/PythonData/envs/imblearn
#
#   added / updated specs:
#     - python=3.8
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2022.4.26  |       hecd8cb5_0         124 KB
#     certifi-2022.5.18.1        |   py38hecd8cb5_0         148 KB
#     libcxx-12.0.0              |       h2f01273_0         805 KB
#     libffi-3.3                 |       hb1e8313_2          44 KB
#     ncurses-6.3                |       hca72f7f_2         856 KB
#     openssl-1.1.1o             |       hca72f7f_0         2.2 MB
#     pip-21.2.4                 |   py38hecd8cb5_0         1.8 MB
#     python-3.8.13              |       hdfd78df_0        10.8 MB
#     readline-8.1.2             |       hca72f7f_1         321 KB
#     setuptools-61.2.0          |   py38hecd8cb5_0        1012 KB
#     sqlite-3.38.3              |       h707629a_0         1.2 MB
#     tk-8.6.12                  |       h5d9f67b_0         3.1 MB
#     wheel-0.37.1               |     pyhd3eb1b0_0          33 KB
#     xz-5.2.5                   |       hca72f7f_1         244 KB
#     zlib-1.2.12                |       h4dc903c_2          94 KB
#     ------------------------------------------------------------
#                                            Total:        22.6 MB
#
# The following NEW packages will be INSTALLED:
#
#   ca-certificates    pkgs/main/osx-64::ca-certificates-2022.4.26-hecd8cb5_0
#   certifi            pkgs/main/osx-64::certifi-2022.5.18.1-py38hecd8cb5_0
#   libcxx             pkgs/main/osx-64::libcxx-12.0.0-h2f01273_0
#   libffi             pkgs/main/osx-64::libffi-3.3-hb1e8313_2
#   ncurses            pkgs/main/osx-64::ncurses-6.3-hca72f7f_2
#   openssl            pkgs/main/osx-64::openssl-1.1.1o-hca72f7f_0
#   pip                pkgs/main/osx-64::pip-21.2.4-py38hecd8cb5_0
#   python             pkgs/main/osx-64::python-3.8.13-hdfd78df_0
#   readline           pkgs/main/osx-64::readline-8.1.2-hca72f7f_1
#   setuptools         pkgs/main/osx-64::setuptools-61.2.0-py38hecd8cb5_0
#   sqlite             pkgs/main/osx-64::sqlite-3.38.3-h707629a_0
#   tk                 pkgs/main/osx-64::tk-8.6.12-h5d9f67b_0
#   wheel              pkgs/main/noarch::wheel-0.37.1-pyhd3eb1b0_0
#   xz                 pkgs/main/osx-64::xz-5.2.5-hca72f7f_1
#   zlib               pkgs/main/osx-64::zlib-1.2.12-h4dc903c_2
#
#
# Proceed ([y]/n)? ^C
#
# CondaSystemExit:
# Operation aborted.  Exiting.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda update conda
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: \
# Warning: 2 possible package resolutions (only showing differing packages):
#   - defaults/noarch::sphinx-4.4.0-pyhd3eb1b0_0, defaults/osx-64::docutils-0.17.1-py37hecd8cb5_1
#   - defaults/osx-64::docutils-0.18.1-py37hecd8cb5_2, defaults/osx-64::sphinx-1.8.5-py37done
#
# ## Package Plan ##
#
#   environment location: /opt/anaconda3/envs/PythonData
#
#   added / updated specs:
#     - conda
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     anyio-3.5.0                |   py37hecd8cb5_0         165 KB
#     argon2-cffi-21.3.0         |     pyhd3eb1b0_0          15 KB
#     argon2-cffi-bindings-21.2.0|   py37hca72f7f_0          32 KB
#     arrow-1.2.2                |     pyhd3eb1b0_0          92 KB
#     asn1crypto-1.5.1           |   py37hecd8cb5_0         167 KB
#     beautifulsoup4-4.11.1      |   py37hecd8cb5_0         188 KB
#     bitarray-2.5.0             |   py37hca72f7f_0         151 KB
#     bokeh-2.4.2                |   py37hecd8cb5_1         7.7 MB
#     bottleneck-1.3.4           |   py37h67323c0_0         116 KB
#     ca-certificates-2022.4.26  |       hecd8cb5_0         124 KB
#     certifi-2022.5.18.1        |   py37hecd8cb5_0         148 KB
#     click-8.0.4                |   py37hecd8cb5_0         150 KB
#     conda-4.13.0               |   py37hecd8cb5_0         900 KB
#     conda-package-handling-1.8.1|   py37hca72f7f_0         1.5 MB
#     cookiecutter-1.7.3         |     pyhd3eb1b0_0          79 KB
#     cryptography-37.0.1        |   py37hf6deb26_0         1.1 MB
#     curl-7.82.0                |       hca72f7f_0          84 KB
#     cython-0.29.28             |   py37he9d5cce_0         1.8 MB
#     daal4py-2021.5.0           |   py37h24a4e90_0         8.5 MB
#     dal-2021.5.0               |     hecd8cb5_782        57.9 MB
#     decorator-5.1.1            |     pyhd3eb1b0_0          12 KB
#     docutils-0.17.1            |   py37hecd8cb5_1         686 KB
#     entrypoints-0.4            |   py37hecd8cb5_0          16 KB
#     expat-2.4.4                |       he9d5cce_0         123 KB
#     filelock-3.6.0             |     pyhd3eb1b0_0          12 KB
#     flask-2.0.3                |     pyhd3eb1b0_0          76 KB
#     fsspec-2022.3.0            |   py37hecd8cb5_0         199 KB
#     gmp-6.2.1                  |       he9d5cce_3         525 KB
#     gmpy2-2.1.2                |   py37hd5de756_0         149 KB
#     importlib-metadata-4.11.3  |   py37hecd8cb5_0          40 KB
#     importlib_metadata-4.11.3  |       hd3eb1b0_0          12 KB
#     importlib_resources-5.2.0  |     pyhd3eb1b0_1          21 KB
#     ipykernel-6.9.1            |   py37hecd8cb5_0         199 KB
#     ipython-7.31.1             |   py37hecd8cb5_0        1015 KB
#     jedi-0.18.1                |   py37hecd8cb5_1         978 KB
#     jinja2-3.0.3               |     pyhd3eb1b0_0         106 KB
#     jinja2-time-0.2.0          |     pyhd3eb1b0_3           9 KB
#     jpeg-9e                    |       hca72f7f_0         225 KB
#     jsonschema-4.4.0           |   py37hecd8cb5_0         120 KB
#     jupyter_core-4.10.0        |   py37hecd8cb5_0          77 KB
#     jupyter_server-1.13.5      |     pyhd3eb1b0_0         259 KB
#     jupyterlab-3.3.2           |     pyhd3eb1b0_0         3.6 MB
#     jupyterlab_server-2.12.0   |   py37hecd8cb5_0          77 KB
#     kiwisolver-1.4.2           |   py37he9d5cce_0          55 KB
#     libcurl-7.82.0             |       h6dfd666_0         314 KB
#     libiconv-1.16              |       hca72f7f_2         695 KB
#     liblief-0.11.5             |       he9d5cce_1         1.6 MB
#     libllvm11-11.1.0           |       h46f1229_1        17.7 MB
#     libssh2-1.10.0             |       h0a4fc7d_0         258 KB
#     libwebp-1.2.2              |       h56c3ce4_0          72 KB
#     libwebp-base-1.2.2         |       hca72f7f_0         393 KB
#     libxml2-2.9.14             |       hbf8cd5e_0         641 KB
#     libxslt-1.1.35             |       h5b33f42_0         420 KB
#     llvmlite-0.38.0            |   py37h8346a28_0         235 KB
#     locket-1.0.0               |   py37hecd8cb5_0          12 KB
#     lxml-4.8.0                 |   py37h65b224f_0         1.1 MB
#     markupsafe-2.1.1           |   py37hca72f7f_0          21 KB
#     matplotlib-3.5.1           |   py37hecd8cb5_1           7 KB
#     matplotlib-base-3.5.1      |   py37hfb0c5b7_1         5.6 MB
#     msgpack-python-1.0.3       |   py37haf03e11_0          74 KB
#     nbclassic-0.3.5            |     pyhd3eb1b0_0          22 KB
#     nbclient-0.5.13            |   py37hecd8cb5_0          90 KB
#     nbconvert-6.4.4            |   py37hecd8cb5_0         495 KB
#     nbformat-5.3.0             |   py37hecd8cb5_0         130 KB
#     nest-asyncio-1.5.5         |   py37hecd8cb5_0          16 KB
#     nltk-3.7                   |     pyhd3eb1b0_0        1010 KB
#     notebook-6.4.11            |   py37hecd8cb5_0         4.2 MB
#     numba-0.55.1               |   py37hae1ba45_0         3.4 MB
#     numpy-1.21.5               |   py37h2e5f0a9_3          11 KB
#     numpy-base-1.21.5          |   py37h3b1a694_3         4.7 MB
#     numpydoc-1.2               |     pyhd3eb1b0_0          45 KB
#     openssl-1.1.1o             |       hca72f7f_0         2.2 MB
#     pandocfilters-1.5.0        |     pyhd3eb1b0_0          11 KB
#     partd-1.2.0                |     pyhd3eb1b0_1          18 KB
#     patsy-0.5.2                |   py37hecd8cb5_1         275 KB
#     pillow-9.0.1               |   py37hde71d04_0         621 KB
#     pkginfo-1.8.2              |     pyhd3eb1b0_0          27 KB
#     pluggy-1.0.0               |   py37hecd8cb5_1          29 KB
#     prometheus_client-0.13.1   |     pyhd3eb1b0_0          47 KB
#     py-1.11.0                  |     pyhd3eb1b0_0          76 KB
#     py-lief-0.11.5             |   py37he9d5cce_1         905 KB
#     pygments-2.11.2            |     pyhd3eb1b0_0         759 KB
#     pyodbc-4.0.32              |   py37he9d5cce_1          68 KB
#     pyopenssl-22.0.0           |     pyhd3eb1b0_0          50 KB
#     pytest-7.1.1               |   py37hecd8cb5_0         459 KB
#     python-fastjsonschema-2.15.1|     pyhd3eb1b0_0          29 KB
#     pywavelets-1.3.0           |   py37hca72f7f_0         3.4 MB
#     qtconsole-5.3.0            |     pyhd3eb1b0_0          93 KB
#     qtpy-2.0.1                 |     pyhd3eb1b0_0          40 KB
#     regex-2022.3.15            |   py37hca72f7f_0         324 KB
#     rope-0.22.0                |     pyhd3eb1b0_0         129 KB
#     scikit-image-0.19.2        |   py37hae1ba45_0         9.3 MB
#     scikit-learn-intelex-2021.5.0|   py37hecd8cb5_0          69 KB
#     setuptools-61.2.0          |   py37hecd8cb5_0        1008 KB
#     six-1.16.0                 |     pyhd3eb1b0_1          18 KB
#     snappy-1.1.9               |       he9d5cce_0         978 KB
#     sphinx-4.4.0               |     pyhd3eb1b0_0         1.2 MB
#     sqlalchemy-1.4.32          |   py37hca72f7f_0         1.9 MB
#     statsmodels-0.13.2         |   py37hca72f7f_0         8.3 MB
#     sympy-1.10.1               |   py37hecd8cb5_0         9.3 MB
#     terminado-0.13.1           |   py37hecd8cb5_0          30 KB
#     tk-8.6.12                  |       h5d9f67b_0         3.1 MB
#     tomli-1.2.2                |     pyhd3eb1b0_0          17 KB
#     tqdm-4.64.0                |   py37hecd8cb5_0         125 KB
#     typing-extensions-4.1.1    |       hd3eb1b0_0           8 KB
#     typing_extensions-4.1.1    |     pyh06a4308_0          28 KB
#     ujson-5.1.0                |   py37he9d5cce_0          51 KB
#     urllib3-1.26.9             |   py37hecd8cb5_0         182 KB
#     websocket-client-0.58.0    |   py37hecd8cb5_4          67 KB
#     werkzeug-2.0.3             |     pyhd3eb1b0_0         221 KB
#     widgetsnbextension-3.5.2   |   py37hecd8cb5_0         650 KB
#     xlsxwriter-3.0.3           |     pyhd3eb1b0_0         113 KB
#     xz-5.2.5                   |       hca72f7f_1         244 KB
#     zipp-3.8.0                 |   py37hecd8cb5_0          16 KB
#     zlib-1.2.12                |       h4dc903c_2          94 KB
#     ------------------------------------------------------------
#                                            Total:       178.8 MB
#
# The following NEW packages will be INSTALLED:
#
#   argon2-cffi-bindi~ pkgs/main/osx-64::argon2-cffi-bindings-21.2.0-py37hca72f7f_0
#   importlib_resourc~ pkgs/main/noarch::importlib_resources-5.2.0-pyhd3eb1b0_1
#   python-fastjsonsc~ pkgs/main/noarch::python-fastjsonschema-2.15.1-pyhd3eb1b0_0
#   tomli              pkgs/main/noarch::tomli-1.2.2-pyhd3eb1b0_0
#   websocket-client   pkgs/main/osx-64::websocket-client-0.58.0-py37hecd8cb5_4
#
# The following packages will be REMOVED:
#
#   python_abi-3.7-2_cp37m
#
# The following packages will be UPDATED:
#
#   anyio                                2.2.0-py37hecd8cb5_1 --> 3.5.0-py37hecd8cb5_0
#   argon2-cffi        pkgs/main/osx-64::argon2-cffi-20.1.0-~ --> pkgs/main/noarch::argon2-cffi-21.3.0-pyhd3eb1b0_0
#   arrow               pkgs/main/osx-64::arrow-0.13.1-py37_0 --> pkgs/main/noarch::arrow-1.2.2-pyhd3eb1b0_0
#   asn1crypto         pkgs/main/noarch::asn1crypto-1.4.0-py~ --> pkgs/main/osx-64::asn1crypto-1.5.1-py37hecd8cb5_0
#   beautifulsoup4     pkgs/main/noarch::beautifulsoup4-4.10~ --> pkgs/main/osx-64::beautifulsoup4-4.11.1-py37hecd8cb5_0
#   bitarray                             2.3.5-py37hca72f7f_0 --> 2.5.0-py37hca72f7f_0
#   bokeh                                2.4.2-py37hecd8cb5_0 --> 2.4.2-py37hecd8cb5_1
#   bottleneck                           1.3.2-py37hf1fa96c_1 --> 1.3.4-py37h67323c0_0
#   ca-certificates    anaconda::ca-certificates-2020.10.14-0 --> pkgs/main::ca-certificates-2022.4.26-hecd8cb5_0
#   certifi                anaconda::certifi-2020.6.20-py37_0 --> pkgs/main::certifi-2022.5.18.1-py37hecd8cb5_0
#   click              pkgs/main/noarch::click-8.0.3-pyhd3eb~ --> pkgs/main/osx-64::click-8.0.4-py37hecd8cb5_0
#   conda                               4.11.0-py37hecd8cb5_0 --> 4.13.0-py37hecd8cb5_0
#   conda-package-han~                   1.7.3-py37h9ed2024_1 --> 1.8.1-py37hca72f7f_0
#   cookiecutter                           1.7.2-pyhd3eb1b0_0 --> 1.7.3-pyhd3eb1b0_0
#   cryptography                        36.0.0-py37hf6deb26_0 --> 37.0.1-py37hf6deb26_0
#   curl                                    7.80.0-hca72f7f_0 --> 7.82.0-hca72f7f_0
#   cython                             0.29.25-py37he9d5cce_0 --> 0.29.28-py37he9d5cce_0
#   daal4py                           2021.4.0-py37h24a4e90_0 --> 2021.5.0-py37h24a4e90_0
#   dal                                 2021.4.0-hecd8cb5_689 --> 2021.5.0-hecd8cb5_782
#   decorator                              5.1.0-pyhd3eb1b0_0 --> 5.1.1-pyhd3eb1b0_0
#   entrypoints                                    0.3-py37_0 --> 0.4-py37hecd8cb5_0
#   expat                                    2.4.1-h23ab428_2 --> 2.4.4-he9d5cce_0
#   filelock                               3.4.2-pyhd3eb1b0_0 --> 3.6.0-pyhd3eb1b0_0
#   flask                                  1.1.2-pyhd3eb1b0_0 --> 2.0.3-pyhd3eb1b0_0
#   fsspec             pkgs/main/noarch::fsspec-2022.1.0-pyh~ --> pkgs/main/osx-64::fsspec-2022.3.0-py37hecd8cb5_0
#   gmp                                      6.2.1-h23ab428_2 --> 6.2.1-he9d5cce_3
#   gmpy2                                2.0.8-py37h6ef4df4_2 --> 2.1.2-py37hd5de756_0
#   importlib-metadata                   4.8.2-py37hecd8cb5_0 --> 4.11.3-py37hecd8cb5_0
#   importlib_metadata                       4.8.2-hd3eb1b0_0 --> 4.11.3-hd3eb1b0_0
#   ipykernel                            6.4.1-py37hecd8cb5_1 --> 6.9.1-py37hecd8cb5_0
#   ipython                             7.29.0-py37h01d92e1_0 --> 7.31.1-py37hecd8cb5_0
#   jedi                                0.18.0-py37hecd8cb5_1 --> 0.18.1-py37hecd8cb5_1
#   jinja2                                2.11.3-pyhd3eb1b0_0 --> 3.0.3-pyhd3eb1b0_0
#   jinja2-time                            0.2.0-pyhd3eb1b0_2 --> 0.2.0-pyhd3eb1b0_3
#   jpeg                                        9d-h9ed2024_0 --> 9e-hca72f7f_0
#   jsonschema         pkgs/main/noarch::jsonschema-3.2.0-py~ --> pkgs/main/osx-64::jsonschema-4.4.0-py37hecd8cb5_0
#   jupyter_core                         4.9.1-py37hecd8cb5_0 --> 4.10.0-py37hecd8cb5_0
#   jupyter_server     pkgs/main/osx-64::jupyter_server-1.4.~ --> pkgs/main/noarch::jupyter_server-1.13.5-pyhd3eb1b0_0
#   jupyterlab                             3.2.1-pyhd3eb1b0_1 --> 3.3.2-pyhd3eb1b0_0
#   jupyterlab_server  pkgs/main/noarch::jupyterlab_server-2~ --> pkgs/main/osx-64::jupyterlab_server-2.12.0-py37hecd8cb5_0
#   kiwisolver                           1.3.1-py37h23ab428_0 --> 1.4.2-py37he9d5cce_0
#   libcurl                                 7.80.0-h6dfd666_0 --> 7.82.0-h6dfd666_0
#   libiconv                                  1.16-h1de35cc_0 --> 1.16-hca72f7f_2
#   liblief                                 0.10.1-h0a44026_0 --> 0.11.5-he9d5cce_1
#   libllvm11                               11.1.0-h9b2ccf5_0 --> 11.1.0-h46f1229_1
#   libssh2                                  1.9.0-ha12b0ac_1 --> 1.10.0-h0a4fc7d_0
#   libwebp                                  1.2.0-hacca55c_0 --> 1.2.2-h56c3ce4_0
#   libwebp-base                             1.2.0-h9ed2024_0 --> 1.2.2-hca72f7f_0
#   libxml2                                 2.9.12-hcdb78fc_0 --> 2.9.14-hbf8cd5e_0
#   libxslt                                 1.1.34-h83b36ba_0 --> 1.1.35-h5b33f42_0
#   llvmlite                            0.37.0-py37he4411ff_1 --> 0.38.0-py37h8346a28_0
#   locket                               0.2.1-py37hecd8cb5_1 --> 1.0.0-py37hecd8cb5_0
#   lxml                                 4.7.1-py37h65b224f_1 --> 4.8.0-py37h65b224f_0
#   markupsafe                           1.1.1-py37h1de35cc_0 --> 2.1.1-py37hca72f7f_0
#   matplotlib                           3.5.0-py37hecd8cb5_0 --> 3.5.1-py37hecd8cb5_1
#   matplotlib-base                      3.5.0-py37h4f681db_0 --> 3.5.1-py37hfb0c5b7_1
#   msgpack-python                       1.0.2-py37hf7b0b51_1 --> 1.0.3-py37haf03e11_0
#   nbclassic                              0.2.6-pyhd3eb1b0_0 --> 0.3.5-pyhd3eb1b0_0
#   nbclient           pkgs/main/noarch::nbclient-0.5.3-pyhd~ --> pkgs/main/osx-64::nbclient-0.5.13-py37hecd8cb5_0
#   nbconvert                            6.3.0-py37hecd8cb5_0 --> 6.4.4-py37hecd8cb5_0
#   nbformat           pkgs/main/noarch::nbformat-5.1.3-pyhd~ --> pkgs/main/osx-64::nbformat-5.3.0-py37hecd8cb5_0
#   nest-asyncio       pkgs/main/noarch::nest-asyncio-1.5.1-~ --> pkgs/main/osx-64::nest-asyncio-1.5.5-py37hecd8cb5_0
#   nltk                                   3.6.5-pyhd3eb1b0_0 --> 3.7-pyhd3eb1b0_0
#   notebook                             6.4.6-py37hecd8cb5_0 --> 6.4.11-py37hecd8cb5_0
#   numba                               0.54.1-py37hae1ba45_0 --> 0.55.1-py37hae1ba45_0
#   numpy                               1.20.3-py37h4b4dc7a_0 --> 1.21.5-py37h2e5f0a9_3
#   numpy-base                          1.20.3-py37he0bd621_0 --> 1.21.5-py37h3b1a694_3
#   numpydoc                               1.1.0-pyhd3eb1b0_1 --> 1.2-pyhd3eb1b0_0
#   openssl                                 1.1.1m-hca72f7f_0 --> 1.1.1o-hca72f7f_0
#   pandocfilters      pkgs/main/osx-64::pandocfilters-1.4.3~ --> pkgs/main/noarch::pandocfilters-1.5.0-pyhd3eb1b0_0
#   partd                                  1.2.0-pyhd3eb1b0_0 --> 1.2.0-pyhd3eb1b0_1
#   patsy                                0.5.2-py37hecd8cb5_0 --> 0.5.2-py37hecd8cb5_1
#   pillow                               8.4.0-py37h98e4679_0 --> 9.0.1-py37hde71d04_0
#   pkginfo            pkgs/main/osx-64::pkginfo-1.7.1-py37h~ --> pkgs/main/noarch::pkginfo-1.8.2-pyhd3eb1b0_0
#   pluggy                               1.0.0-py37hecd8cb5_0 --> 1.0.0-py37hecd8cb5_1
#   prometheus_client                     0.12.0-pyhd3eb1b0_0 --> 0.13.1-pyhd3eb1b0_0
#   py                                    1.10.0-pyhd3eb1b0_0 --> 1.11.0-pyhd3eb1b0_0
#   py-lief                             0.10.1-py37haf313ee_0 --> 0.11.5-py37he9d5cce_1
#   pygments                              2.10.0-pyhd3eb1b0_0 --> 2.11.2-pyhd3eb1b0_0
#   pyodbc                              4.0.32-py37he9d5cce_0 --> 4.0.32-py37he9d5cce_1
#   pyopenssl                             21.0.0-pyhd3eb1b0_1 --> 22.0.0-pyhd3eb1b0_0
#   pytest                               6.2.5-py37hecd8cb5_2 --> 7.1.1-py37hecd8cb5_0
#   pywavelets                           1.1.1-py37haf1e3a3_2 --> 1.3.0-py37hca72f7f_0
#   qtconsole                              5.1.1-pyhd3eb1b0_0 --> 5.3.0-pyhd3eb1b0_0
#   qtpy                                  1.10.0-pyhd3eb1b0_0 --> 2.0.1-pyhd3eb1b0_0
#   regex                            2021.11.2-py37hca72f7f_0 --> 2022.3.15-py37hca72f7f_0
#   rope                                  0.21.1-pyhd3eb1b0_0 --> 0.22.0-pyhd3eb1b0_0
#   scikit-image                        0.18.3-py37hae1ba45_0 --> 0.19.2-py37hae1ba45_0
#   scikit-learn-inte~                2021.4.0-py37hecd8cb5_0 --> 2021.5.0-py37hecd8cb5_0
#   setuptools                          58.0.4-py37hecd8cb5_0 --> 61.2.0-py37hecd8cb5_0
#   six                                   1.16.0-pyhd3eb1b0_0 --> 1.16.0-pyhd3eb1b0_1
#   snappy                                   1.1.8-hb1e8313_0 --> 1.1.9-he9d5cce_0
#   sphinx              pkgs/main/osx-64::sphinx-1.8.5-py37_0 --> pkgs/main/noarch::sphinx-4.4.0-pyhd3eb1b0_0
#   sqlalchemy                          1.4.27-py37hca72f7f_0 --> 1.4.32-py37hca72f7f_0
#   statsmodels                         0.12.2-py37h9ed2024_0 --> 0.13.2-py37hca72f7f_0
#   sympy                                  1.9-py37hecd8cb5_0 --> 1.10.1-py37hecd8cb5_0
#   terminado                            0.9.4-py37hecd8cb5_0 --> 0.13.1-py37hecd8cb5_0
#   tk                                      8.6.11-h7bc2e8c_0 --> 8.6.12-h5d9f67b_0
#   tqdm               pkgs/main/noarch::tqdm-4.62.3-pyhd3eb~ --> pkgs/main/osx-64::tqdm-4.64.0-py37hecd8cb5_0
#   typing-extensions                     3.10.0.2-hd3eb1b0_0 --> 4.1.1-hd3eb1b0_0
#   typing_extensions                   3.10.0.2-pyh06a4308_0 --> 4.1.1-pyh06a4308_0
#   ujson                                4.2.0-py37he9d5cce_0 --> 5.1.0-py37he9d5cce_0
#   urllib3            pkgs/main/noarch::urllib3-1.26.7-pyhd~ --> pkgs/main/osx-64::urllib3-1.26.9-py37hecd8cb5_0
#   werkzeug                               2.0.2-pyhd3eb1b0_0 --> 2.0.3-pyhd3eb1b0_0
#   widgetsnbextension                           3.5.1-py37_0 --> 3.5.2-py37hecd8cb5_0
#   xlsxwriter                             3.0.2-pyhd3eb1b0_0 --> 3.0.3-pyhd3eb1b0_0
#   xz                                       5.2.5-h1de35cc_0 --> 5.2.5-hca72f7f_1
#   zipp               pkgs/main/noarch::zipp-3.7.0-pyhd3eb1~ --> pkgs/main/osx-64::zipp-3.8.0-py37hecd8cb5_0
#   zlib                                    1.2.11-h4dc903c_4 --> 1.2.12-h4dc903c_2
#
# The following packages will be DOWNGRADED:
#
#   docutils                            0.18.1-py37hecd8cb5_2 --> 0.17.1-py37hecd8cb5_1
#
#
#
# Downloading and Extracting Packages
# argon2-cffi-bindings | 32 KB     | ##################################### | 100%
# typing-extensions-4. | 8 KB      | ##################################### | 100%
# ipython-7.31.1       | 1015 KB   | ##################################### | 100%
# libllvm11-11.1.0     | 17.7 MB   | ##################################### | 100%
# llvmlite-0.38.0      | 235 KB    | ##################################### | 100%
# cryptography-37.0.1  | 1.1 MB    | ##################################### | 100%
# libcurl-7.82.0       | 314 KB    | ##################################### | 100%
# jupyter_server-1.13. | 259 KB    | ##################################### | 100%
# jpeg-9e              | 225 KB    | ##################################### | 100%
# pluggy-1.0.0         | 29 KB     | ##################################### | 100%
# matplotlib-base-3.5. | 5.6 MB    | ##################################### | 100%
# kiwisolver-1.4.2     | 55 KB     | ##################################### | 100%
# zlib-1.2.12          | 94 KB     | ##################################### | 100%
# expat-2.4.4          | 123 KB    | ##################################### | 100%
# scikit-learn-intelex | 69 KB     | ##################################### | 100%
# nbformat-5.3.0       | 130 KB    | ##################################### | 100%
# nbconvert-6.4.4      | 495 KB    | ##################################### | 100%
# ipykernel-6.9.1      | 199 KB    | ##################################### | 100%
# bottleneck-1.3.4     | 116 KB    | ##################################### | 100%
# regex-2022.3.15      | 324 KB    | ##################################### | 100%
# jsonschema-4.4.0     | 120 KB    | ##################################### | 100%
# rope-0.22.0          | 129 KB    | ##################################### | 100%
# pygments-2.11.2      | 759 KB    | ##################################### | 100%
# pywavelets-1.3.0     | 3.4 MB    | ##################################### | 100%
# pyodbc-4.0.32        | 68 KB     | ##################################### | 100%
# markupsafe-2.1.1     | 21 KB     | ##################################### | 100%
# filelock-3.6.0       | 12 KB     | ##################################### | 100%
# tomli-1.2.2          | 17 KB     | ##################################### | 100%
# flask-2.0.3          | 76 KB     | ##################################### | 100%
# werkzeug-2.0.3       | 221 KB    | ##################################### | 100%
# xlsxwriter-3.0.3     | 113 KB    | ##################################### | 100%
# nest-asyncio-1.5.5   | 16 KB     | ##################################### | 100%
# asn1crypto-1.5.1     | 167 KB    | ##################################### | 100%
# libxml2-2.9.14       | 641 KB    | ##################################### | 100%
# fsspec-2022.3.0      | 199 KB    | ##################################### | 100%
# libssh2-1.10.0       | 258 KB    | ##################################### | 100%
# websocket-client-0.5 | 67 KB     | ##################################### | 100%
# entrypoints-0.4      | 16 KB     | ##################################### | 100%
# docutils-0.17.1      | 686 KB    | ##################################### | 100%
# bitarray-2.5.0       | 151 KB    | ##################################### | 100%
# jinja2-3.0.3         | 106 KB    | ##################################### | 100%
# sphinx-4.4.0         | 1.2 MB    | ##################################### | 100%
# libwebp-base-1.2.2   | 393 KB    | ##################################### | 100%
# locket-1.0.0         | 12 KB     | ##################################### | 100%
# libxslt-1.1.35       | 420 KB    | ##################################### | 100%
# python-fastjsonschem | 29 KB     |                                       |   0%
# msgpack-python-1.0.3 | 74 KB     | ##################################### | 100%
# argon2-cffi-21.3.0   | 15 KB     | ##################################### | 100%
# six-1.16.0           | 18 KB     | ##################################### | 100%
# conda-package-handli | 1.5 MB    |                                       |   0%
# patsy-0.5.2          | 275 KB    |                                       |   0%
# snappy-1.1.9         | 978 KB    |                                       |   0%
# qtpy-2.0.1           | 40 KB     |                                       |   0%
# py-1.11.0            | 76 KB     |                                       |   0%
# cython-0.29.28       | 1.8 MB    |                                       |   0%
# lxml-4.8.0           | 1.1 MB    |                                       |   0%
# jedi-0.18.1          | 978 KB    |                                       |   0%
# py-lief-0.11.5       | 905 KB    |                                       |   0%
# daal4py-2021.5.0     | 8.5 MB    |                                       |   0%
# pillow-9.0.1         | 621 KB    |                                       |   0%
# numpydoc-1.2         | 45 KB     |                                       |   0%
# cookiecutter-1.7.3   | 79 KB     |                                       |   0%
# arrow-1.2.2          | 92 KB     |                                       |   0%
# pytest-7.1.1         | 459 KB    |                                       |   0%
# importlib_metadata-4 | 12 KB     |                                       |   0%
# matplotlib-3.5.1     | 7 KB      | ##################################### | 100%
# bokeh-2.4.2          | 7.7 MB    |                                       |   0%
# prometheus_client-0. | 47 KB     |                                       |   0%
# terminado-0.13.1     | 30 KB     |                                       |   0%
# pkginfo-1.8.2        | 27 KB     |                                       |   0%
# importlib-metadata-4 | 40 KB     |                                       |   0%
# setuptools-61.2.0    | 1008 KB   |                                       |   0%
# notebook-6.4.11      | 4.2 MB    |                                       |   0%
# liblief-0.11.5       | 1.6 MB    |                                       |   0%
# jupyterlab_server-2. | 77 KB     |                                       |   0%
# conda-4.13.0         | 900 KB    |                                       |   0%
# pandocfilters-1.5.0  | 11 KB     | ##################################### | 100%
# gmp-6.2.1            | 525 KB    |                                       |   0%
# typing_extensions-4. | 28 KB     |                                       |   0%
# gmpy2-2.1.2          | 149 KB    |                                       |   0%
# urllib3-1.26.9       | 182 KB    |                                       |   0%
# nbclient-0.5.13      | 90 KB     |                                       |   0%
# zipp-3.8.0           | 16 KB     |                                       |   0%
# jupyterlab-3.3.2     | 3.6 MB    |                                       |   0%
# xz-5.2.5             | 244 KB    | #######2                              |  20%
# partd-1.2.0          | 18 KB     |                                       |   0%
# ca-certificates-2022 | 124 KB    |                                       |   0%
# curl-7.82.0          | 84 KB     |                                       |   0%
# libiconv-1.16        | 695 KB    |                                       |   0%
# jupyter_core-4.10.0  | 77 KB     |                                       |   0%
# beautifulsoup4-4.11. | 188 KB    |                                       |   0%
# statsmodels-0.13.2   | 8.3 MB    |                                       |   0%
# click-8.0.4          | 150 KB    |                                       |   0%
# qtconsole-5.3.0      | 93 KB     |                                       |   0%
# sqlalchemy-1.4.32    | 1.9 MB    |                                       |   0%
# openssl-1.1.1o       | 2.2 MB    |                                       |   0%
# scikit-image-0.19.2  | 9.3 MB    |                                       |   0%
# ujson-5.1.0          | 51 KB     |                                       |   0%
# tqdm-4.64.0          | 125 KB    |                                       |   0%
# tk-8.6.12            | 3.1 MB    |                                       |   0%
# anyio-3.5.0          | 165 KB    |                                       |   0%
# importlib_resources- | 21 KB     |                                       |   0%
# sympy-1.10.1         | 9.3 MB    |                                       |   0%
# numpy-base-1.21.5    | 4.7 MB    |                                       |   0%
# dal-2021.5.0         | 57.9 MB   |                                       |   0%
# numpy-1.21.5         | 11 KB     |                                       |   0%
# libwebp-1.2.2        | 72 KB     |                                       |   0%
# numba-0.55.1         | 3.4 MB    |                                       |   0%
# nltk-3.7             | 1010 KB   |                                       |   0%
# certifi-2022.5.18.1  | 148 KB    |                                       |   0%
# jinja2-time-0.2.0    | 9 KB      |                                       |   0%
# pyopenssl-22.0.0     | 50 KB     |                                       |   0%
# widgetsnbextension-3 | 650 KB    |                                       |   0%
# decorator-5.1.1      | 12 KB     |                                       |   0%
# nbclassic-0.3.5      | 22 KB     |                                       |   0%
#
# InvalidArchiveError("Error with archive /opt/anaconda3/envs/PythonData/pkgs/sphinx-4.4.0-pyhd3eb1b0_064fjug8w/pkg-sphinx-4.4.0-pyhd3eb1b0_0.tar.zst.  You probably need to delete and re-download or re-create this file.  Message from libarchive was:\n\nFailed to create dir 'site-packages/sphinx/locale/sv'")
# InvalidArchiveError('Error with archive /opt/anaconda3/envs/PythonData/pkgs/libxslt-1.1.35-h5b33f42_0_wyjmbq1/pkg-libxslt-1.1.35-h5b33f42_0.tar.zst.  You probably need to delete and re-download or re-create this file.  Message from libarchive was:\n\nWrite to restore size failed')
# [Errno 28] No space left on device: '/opt/anaconda3/envs/PythonData/pkgs/python-fastjsonschema-2.15.1-pyhd3eb1b0_0.conda'
# InvalidArchiveError("Error with archive /opt/anaconda3/envs/PythonData/pkgs/msgpack-python-1.0.3-py37haf03e11_0yaa_a3cu/pkg-msgpack-python-1.0.3-py37haf03e11_0.tar.zst.  You probably need to delete and re-download or re-create this file.  Message from libarchive was:\n\nFailed to create dir 'lib/python3.7/site-packages/msgpack/__pycache__'")
# [Errno 28] No space left on device
# InvalidArchiveError("Error with archive /opt/anaconda3/envs/PythonData/pkgs/six-1.16.0-pyhd3eb1b0_17y9qw5a_/info-six-1.16.0-pyhd3eb1b0_1.tar.zst.  You probably need to delete and re-download or re-create this file.  Message from libarchive was:\n\nFailed to create dir 'info/recipe'")
# CondaError: Failed to write to /opt/anaconda3/envs/PythonData/pkgs/conda-package-handling-1.8.1-py37hca72f7f_0.conda
#   errno: 28
# CondaError: Failed to write to /opt/anaconda3/envs/PythonData/pkgs/patsy-0.5.2-py37hecd8cb5_1.conda
#   errno: 28
# CondaError: Failed to write to /opt/anaconda3/envs/PythonData/pkgs/snappy-1.1.9-he9d5cce_0.conda
#   errno: 28
# CondaError: Failed to write to /opt/anaconda3/envs/PythonData/pkgs/qtpy-2.0.1-pyhd3eb1b0_0.conda
#   errno: 28
# CondaError: Failed to write to /opt/anaconda3/envs/PythonData/pkgs/py-1.11.0-pyhd3eb1b0_0.conda
#   errno: 28
# CondaError: Failed to write to /opt/anaconda3/envs/PythonData/pkgs/cython-0.29.28-py37he9d5cce_0.conda
#   errno: 28
# CondaError: Failed to write to /opt/anaconda3/envs/PythonData/pkgs/lxml-4.8.0-py37h65b224f_0.conda
#   errno: 28
# CondaError: Failed to write to /opt/anaconda3/envs/PythonData/pkgs/jedi-0.18.1-py37hecd8cb5_1.conda
#   errno: 28
# CondaError: Failed to write to /opt/anaconda3/envs/PythonData/pkgs/py-lief-0.11.5-py37he9d5cce_1.conda
#   errno: 28
# CondaError: Failed to write to /opt/anaconda3/envs/PythonData/pkgs/daal4py-2021.5.0-py37h24a4e90_0.conda
#   errno: 28
# [Errno 28] No space left on device: '/opt/anaconda3/envs/PythonData/pkgs/pillow-9.0.1-py37hde71d04_0.conda'
# [Errno 28] No space left on device: '/opt/anaconda3/envs/PythonData/pkgs/numpydoc-1.2-pyhd3eb1b0_0.conda'
# [Errno 28] No space left on device: '/opt/anaconda3/envs/PythonData/pkgs/cookiecutter-1.7.3-pyhd3eb1b0_0.conda'
# [Errno 28] No space left on device: '/opt/anaconda3/envs/PythonData/pkgs/arrow-1.2.2-pyhd3eb1b0_0.conda'
# CondaError: Failed to write to /opt/anaconda3/envs/PythonData/pkgs/pytest-7.1.1-py37hecd8cb5_0.conda
#   errno: 28
# CondaError: Failed to write to /opt/anaconda3/envs/PythonData/pkgs/importlib_metadata-4.11.3-hd3eb1b0_0.conda
#   errno: 28
# [Errno 28] No space left on device: '/opt/anaconda3/envs/PythonData/pkgs/matplotlib-3.5.1-py37hecd8cb5_1'
# CondaError: Failed to write to /opt/anaconda3/envs/PythonData/pkgs/bokeh-2.4.2-py37hecd8cb5_1.conda
#   errno: 28
# [Errno 28] No space left on device: '/opt/anaconda3/envs/PythonData/pkgs/prometheus_client-0.13.1-pyhd3eb1b0_0.conda'
# CondaError: Failed to write to /opt/anaconda3/envs/PythonData/pkgs/terminado-0.13.1-py37hecd8cb5_0.conda
#   errno: 28
# CondaError: Failed to write to /opt/anaconda3/envs/PythonData/pkgs/pkginfo-1.8.2-pyhd3eb1b0_0.conda
#   errno: 28
# CondaError: Failed to write to /opt/anaconda3/envs/PythonData/pkgs/importlib-metadata-4.11.3-py37hecd8cb5_0.conda
#   errno: 28
# CondaError: Failed to write to /opt/anaconda3/envs/PythonData/pkgs/setuptools-61.2.0-py37hecd8cb5_0.conda
#   errno: 28
# CondaError: Failed to write to /opt/anaconda3/envs/PythonData/pkgs/notebook-6.4.11-py37hecd8cb5_0.conda
#   errno: 28
# CondaError: Failed to write to /opt/anaconda3/envs/PythonData/pkgs/liblief-0.11.5-he9d5cce_1.conda
#   errno: 28
# CondaError: Failed to write to /opt/anaconda3/envs/PythonData/pkgs/jupyterlab_server-2.12.0-py37hecd8cb5_0.conda
#   errno: 28
# CondaError: Failed to write to /opt/anaconda3/envs/PythonData/pkgs/conda-4.13.0-py37hecd8cb5_0.conda
#   errno: 28
# [Errno 28] No space left on device: '/opt/anaconda3/envs/PythonData/pkgs/pandocfilters-1.5.0-pyhd3eb1b0_0asex4j_a'
# [Errno 28] No space left on device: '/opt/anaconda3/envs/PythonData/pkgs/gmp-6.2.1-he9d5cce_3.conda'
# CondaError: Failed to write to /opt/anaconda3/envs/PythonData/pkgs/typing_extensions-4.1.1-pyh06a4308_0.conda
#   errno: 28
# CondaError: Failed to write to /opt/anaconda3/envs/PythonData/pkgs/gmpy2-2.1.2-py37hd5de756_0.conda
#   errno: 28
# CondaError: Failed to write to /opt/anaconda3/envs/PythonData/pkgs/urllib3-1.26.9-py37hecd8cb5_0.conda
#   errno: 28
# CondaError: Failed to write to /opt/anaconda3/envs/PythonData/pkgs/nbclient-0.5.13-py37hecd8cb5_0.conda
#   errno: 28
# CondaError: Failed to write to /opt/anaconda3/envs/PythonData/pkgs/zipp-3.8.0-py37hecd8cb5_0.conda
#   errno: 28
# CondaError: Failed to write to /opt/anaconda3/envs/PythonData/pkgs/jupyterlab-3.3.2-pyhd3eb1b0_0.conda
#   errno: 28
# CondaError: Failed to write to /opt/anaconda3/envs/PythonData/pkgs/xz-5.2.5-hca72f7f_1.conda
#   errno: 28
# [Errno 28] No space left on device: '/opt/anaconda3/envs/PythonData/pkgs/partd-1.2.0-pyhd3eb1b0_1.conda'
# [Errno 28] No space left on device: '/opt/anaconda3/envs/PythonData/pkgs/ca-certificates-2022.4.26-hecd8cb5_0.conda'
# [Errno 28] No space left on device: '/opt/anaconda3/envs/PythonData/pkgs/curl-7.82.0-hca72f7f_0.conda'
# [Errno 28] No space left on device: '/opt/anaconda3/envs/PythonData/pkgs/libiconv-1.16-hca72f7f_2.conda'
# [Errno 28] No space left on device: '/opt/anaconda3/envs/PythonData/pkgs/jupyter_core-4.10.0-py37hecd8cb5_0.conda'
# [Errno 28] No space left on device: '/opt/anaconda3/envs/PythonData/pkgs/beautifulsoup4-4.11.1-py37hecd8cb5_0.conda'
# [Errno 28] No space left on device: '/opt/anaconda3/envs/PythonData/pkgs/statsmodels-0.13.2-py37hca72f7f_0.conda'
# [Errno 28] No space left on device: '/opt/anaconda3/envs/PythonData/pkgs/click-8.0.4-py37hecd8cb5_0.conda'
# [Errno 28] No space left on device: '/opt/anaconda3/envs/PythonData/pkgs/qtconsole-5.3.0-pyhd3eb1b0_0.conda'
# [Errno 28] No space left on device: '/opt/anaconda3/envs/PythonData/pkgs/sqlalchemy-1.4.32-py37hca72f7f_0.conda'
# CondaError: Failed to write to /opt/anaconda3/envs/PythonData/pkgs/openssl-1.1.1o-hca72f7f_0.conda
#   errno: 28
# CondaError: Failed to write to /opt/anaconda3/envs/PythonData/pkgs/scikit-image-0.19.2-py37hae1ba45_0.conda
#   errno: 28
# CondaError: Failed to write to /opt/anaconda3/envs/PythonData/pkgs/ujson-5.1.0-py37he9d5cce_0.conda
#   errno: 28
# CondaError: Failed to write to /opt/anaconda3/envs/PythonData/pkgs/tqdm-4.64.0-py37hecd8cb5_0.conda
#   errno: 28
# CondaError: Failed to write to /opt/anaconda3/envs/PythonData/pkgs/tk-8.6.12-h5d9f67b_0.conda
#   errno: 28
# CondaError: Failed to write to /opt/anaconda3/envs/PythonData/pkgs/anyio-3.5.0-py37hecd8cb5_0.conda
#   errno: 28
# CondaError: Failed to write to /opt/anaconda3/envs/PythonData/pkgs/importlib_resources-5.2.0-pyhd3eb1b0_1.conda
#   errno: 28
# CondaError: Failed to write to /opt/anaconda3/envs/PythonData/pkgs/sympy-1.10.1-py37hecd8cb5_0.conda
#   errno: 28
# [Errno 28] No space left on device: '/opt/anaconda3/envs/PythonData/pkgs/numpy-base-1.21.5-py37h3b1a694_3.conda'
# CondaError: Failed to write to /opt/anaconda3/envs/PythonData/pkgs/dal-2021.5.0-hecd8cb5_782.conda
#   errno: 28
# CondaError: Failed to write to /opt/anaconda3/envs/PythonData/pkgs/numpy-1.21.5-py37h2e5f0a9_3.conda
#   errno: 28
# CondaError: Failed to write to /opt/anaconda3/envs/PythonData/pkgs/libwebp-1.2.2-h56c3ce4_0.conda
#   errno: 28
# CondaError: Failed to write to /opt/anaconda3/envs/PythonData/pkgs/numba-0.55.1-py37hae1ba45_0.conda
#   errno: 28
# CondaError: Failed to write to /opt/anaconda3/envs/PythonData/pkgs/nltk-3.7-pyhd3eb1b0_0.conda
#   errno: 28
# CondaError: Failed to write to /opt/anaconda3/envs/PythonData/pkgs/certifi-2022.5.18.1-py37hecd8cb5_0.conda
#   errno: 28
# CondaError: Failed to write to /opt/anaconda3/envs/PythonData/pkgs/jinja2-time-0.2.0-pyhd3eb1b0_3.conda
#   errno: 28
# CondaError: Failed to write to /opt/anaconda3/envs/PythonData/pkgs/pyopenssl-22.0.0-pyhd3eb1b0_0.conda
#   errno: 28
# CondaError: Failed to write to /opt/anaconda3/envs/PythonData/pkgs/widgetsnbextension-3.5.2-py37hecd8cb5_0.conda
#   errno: 28
# CondaError: Failed to write to /opt/anaconda3/envs/PythonData/pkgs/decorator-5.1.1-pyhd3eb1b0_0.conda
#   errno: 28
# CondaError: Failed to write to /opt/anaconda3/envs/PythonData/pkgs/nbclassic-0.3.5-pyhd3eb1b0_0.conda
#   errno: 28
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Read the CSV and Perform Basic Data Cleaning

# %%
columns = [
    "loan_amnt", "int_rate", "installment", "home_ownership",
    "annual_inc", "verification_status", "issue_d", "loan_status",
    "pymnt_plan", "dti", "delinq_2yrs", "inq_last_6mths",
    "open_acc", "pub_rec", "revol_bal", "total_acc",
    "initial_list_status", "out_prncp", "out_prncp_inv", "total_pymnt",
    "total_pymnt_inv", "total_rec_prncp", "total_rec_int", "total_rec_late_fee",
    "recoveries", "collection_recovery_fee", "last_pymnt_amnt", "next_pymnt_d",
    "collections_12_mths_ex_med", "policy_code", "application_type", "acc_now_delinq",
    "tot_coll_amt", "tot_cur_bal", "open_acc_6m", "open_act_il",
    "open_il_12m", "open_il_24m", "mths_since_rcnt_il", "total_bal_il",
    "il_util", "open_rv_12m", "open_rv_24m", "max_bal_bc",
    "all_util", "total_rev_hi_lim", "inq_fi", "total_cu_tl",
    "inq_last_12m", "acc_open_past_24mths", "avg_cur_bal", "bc_open_to_buy",
    "bc_util", "chargeoff_within_12_mths", "delinq_amnt", "mo_sin_old_il_acct",
    "mo_sin_old_rev_tl_op", "mo_sin_rcnt_rev_tl_op", "mo_sin_rcnt_tl", "mort_acc",
    "mths_since_recent_bc", "mths_since_recent_inq", "num_accts_ever_120_pd", "num_actv_bc_tl",
    "num_actv_rev_tl", "num_bc_sats", "num_bc_tl", "num_il_tl",
    "num_op_rev_tl", "num_rev_accts", "num_rev_tl_bal_gt_0",
    "num_sats", "num_tl_120dpd_2m", "num_tl_30dpd", "num_tl_90g_dpd_24m",
    "num_tl_op_past_12m", "pct_tl_nvr_dlq", "percent_bc_gt_75", "pub_rec_bankruptcies",
    "tax_liens", "tot_hi_cred_lim", "total_bal_ex_mort", "total_bc_limit",
    "total_il_high_credit_limit", "hardship_flag", "debt_settlement_flag"
]

target = ["loan_status"]

# %%
# Load the data
file_path = Path('LoanStats_2019Q1.csv')
df = pd.read_csv(file_path, skiprows=1)[:-2]
df = df.loc[:, columns].copy()

# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')

# Drop the null rows
df = df.dropna()

# Remove the `Issued` loan status
issued_mask = df['loan_status'] != 'Issued'
df = df.loc[issued_mask]

# convert interest rate to numerical
df['int_rate'] = df['int_rate'].str.replace('%', '')
df['int_rate'] = df['int_rate'].astype('float') / 100


# Convert the target column values to low_risk and high_risk based on their values
x = {'Current': 'low_risk'}   
df = df.replace(x)

x = dict.fromkeys(['Late (31-120 days)', 'Late (16-30 days)', 'Default', 'In Grace Period'], 'high_risk')    
df = df.replace(x)

df.reset_index(inplace=True, drop=True)

df.head()
# Out:
#    loan_amnt  int_rate  installment home_ownership  annual_inc  \
# 0    10500.0    0.1719       375.35           RENT     66000.0
# 1    25000.0    0.2000       929.09       MORTGAGE    105000.0
# 2    20000.0    0.2000       529.88       MORTGAGE     56000.0
# 3    10000.0    0.1640       353.55           RENT     92000.0
# 4    22000.0    0.1474       520.39       MORTGAGE     52000.0
#
#   verification_status   issue_d loan_status pymnt_plan    dti  ...  \
# 0     Source Verified  Mar-2019    low_risk          n  27.24  ...
# 1            Verified  Mar-2019    low_risk          n  20.23  ...
# 2            Verified  Mar-2019    low_risk          n  24.26  ...
# 3            Verified  Mar-2019    low_risk          n  31.44  ...
# 4        Not Verified  Mar-2019    low_risk          n  18.76  ...
#
#    pct_tl_nvr_dlq  percent_bc_gt_75  pub_rec_bankruptcies  tax_liens  \
# 0            85.7             100.0                   0.0        0.0
# 1            91.2              50.0                   1.0        0.0
# 2            66.7              50.0                   0.0        0.0
# 3           100.0              50.0                   1.0        0.0
# 4           100.0               0.0                   0.0        0.0
#
#    tot_hi_cred_lim  total_bal_ex_mort total_bc_limit  \
# 0          65687.0            38199.0         2000.0
# 1         271427.0            60641.0        41200.0
# 2          60644.0            45684.0         7500.0
# 3          99506.0            68784.0        19700.0
# 4         219750.0            25919.0        27600.0
#
#    total_il_high_credit_limit  hardship_flag  debt_settlement_flag
# 0                     61987.0              N                     N
# 1                     49197.0              N                     N
# 2                     43144.0              N                     N
# 3                     76506.0              N                     N
# 4                     20000.0              N                     N
#
# [5 rows x 86 columns]

# %% [markdown]
# # Split the Data into Training and Testing

# %%
# Create our features
X = pd.get_dummies(df.drop(columns='loan_status'))

# Create our target
y = df['loan_status']

# %%
X.describe()
# Out:
#           loan_amnt      int_rate   installment    annual_inc           dti  \
# count  68817.000000  68817.000000  68817.000000  6.881700e+04  68817.000000
# mean   16677.594562      0.127718    480.652863  8.821371e+04     21.778153
# std    10277.348590      0.048130    288.062432  1.155800e+05     20.199244
# min     1000.000000      0.060000     30.890000  4.000000e+01      0.000000
# 25%     9000.000000      0.088100    265.730000  5.000000e+04     13.890000
# 50%    15000.000000      0.118000    404.560000  7.300000e+04     19.760000
# 75%    24000.000000      0.155700    648.100000  1.040000e+05     26.660000
# max    40000.000000      0.308400   1676.230000  8.797500e+06    999.000000
#
#         delinq_2yrs  inq_last_6mths      open_acc       pub_rec  \
# count  68817.000000    68817.000000  68817.000000  68817.000000
# mean       0.217766        0.497697     12.587340      0.126030
# std        0.718367        0.758122      6.022869      0.336797
# min        0.000000        0.000000      2.000000      0.000000
# 25%        0.000000        0.000000      8.000000      0.000000
# 50%        0.000000        0.000000     11.000000      0.000000
# 75%        0.000000        1.000000     16.000000      0.000000
# max       18.000000        5.000000     72.000000      4.000000
#
#            revol_bal  ...  issue_d_Mar-2019  pymnt_plan_n  \
# count   68817.000000  ...      68817.000000       68817.0
# mean    17604.142828  ...          0.177238           1.0
# std     21835.880400  ...          0.381873           0.0
# min         0.000000  ...          0.000000           1.0
# 25%      6293.000000  ...          0.000000           1.0
# 50%     12068.000000  ...          0.000000           1.0
# 75%     21735.000000  ...          0.000000           1.0
# max    587191.000000  ...          1.000000           1.0
#
#        initial_list_status_f  initial_list_status_w  next_pymnt_d_Apr-2019  \
# count           68817.000000           68817.000000           68817.000000
# mean                0.123879               0.876121               0.383161
# std                 0.329446               0.329446               0.486161
# min                 0.000000               0.000000               0.000000
# 25%                 0.000000               1.000000               0.000000
# 50%                 0.000000               1.000000               0.000000
# 75%                 0.000000               1.000000               1.000000
# max                 1.000000               1.000000               1.000000
#
#        next_pymnt_d_May-2019  application_type_Individual  \
# count           68817.000000                 68817.000000
# mean                0.616839                     0.860340
# std                 0.486161                     0.346637
# min                 0.000000                     0.000000
# 25%                 0.000000                     1.000000
# 50%                 1.000000                     1.000000
# 75%                 1.000000                     1.000000
# max                 1.000000                     1.000000
#
#        application_type_Joint App  hardship_flag_N  debt_settlement_flag_N
# count                68817.000000          68817.0                 68817.0
# mean                     0.139660              1.0                     1.0
# std                      0.346637              0.0                     0.0
# min                      0.000000              1.0                     1.0
# 25%                      0.000000              1.0                     1.0
# 50%                      0.000000              1.0                     1.0
# 75%                      0.000000              1.0                     1.0
# max                      1.000000              1.0                     1.0
#
# [8 rows x 95 columns]

# %%
# Check the balance of our target values
y.value_counts()
# Out:
# low_risk     68470
# high_risk      347
# Name: loan_status, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1, stratify=y)
X_train.shape
# Out:
# (51612, 95)

# %% [markdown]
# # Oversampling
#
# In this section, you will compare two oversampling algorithms to determine which algorithm results in the best performance. You will oversample the data using the naive random oversampling algorithm and the SMOTE algorithm. For each algorithm, be sure to complete the folliowing steps:
#
# 1. View the count of the target classes using `Counter` from the collections library.
# 3. Use the resampled data to train a logistic regression model.
# 3. Calculate the balanced accuracy score from sklearn.metrics.
# 4. Print the confusion matrix from sklearn.metrics.
# 5. Generate a classication report using the `imbalanced_classification_report` from imbalanced-learn.
#
# Note: Use a random state of 1 for each sampling algorithm to ensure consistency between tests

# %% [markdown]
# ### Naive Random Oversampling

# %%
# Resample the training data with the RandomOversampler
from imblearn.over_sampling import RandomOverSampler
ros = RandomOverSampler(random_state=1)
X_resampled, y_resampled = ros.fit_resample(X_train, y_train)
Counter(y_resampled)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/0s/9pgh43n143n123rjw56tynrr0000gn/T/ipykernel_5435/1390449478.py in <module>
#       1 # Resample the training data with the RandomOversampler
# ----> 2 from imblearn.over_sampling import RandomOverSampler
#       3 ros = RandomOverSampler(random_state=1)
#       4 X_resampled, y_resampled = ros.fit_resample(X_train, y_train)
#       5 Counter(y_resampled)
#
# ModuleNotFoundError: No module named 'imblearn'

# %%
# Train the Logistic Regression model using the resampled data
from sklearn.linear_model import LogisticRegression
model = LogisticRegression(solver='lbfgs', random_state=1)
model.fit(X_resampled, y_resampled)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/0s/9pgh43n143n123rjw56tynrr0000gn/T/ipykernel_5435/1881643603.py in <module>
#       2 from sklearn.linear_model import LogisticRegression
#       3 model = LogisticRegression(solver='lbfgs', random_state=1)
# ----> 4 model.fit(X_resampled, y_resampled)
#
# NameError: name 'X_resampled' is not defined

# %%
# Calculated the balanced accuracy score
from sklearn.metrics import balanced_accuracy_score
y_pred = model.predict(X_test)
balanced_accuracy_score(y_test, y_pred)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# /var/folders/0s/9pgh43n143n123rjw56tynrr0000gn/T/ipykernel_5435/2945958662.py in <module>
#       1 # Calculated the balanced accuracy score
#       2 from sklearn.metrics import balanced_accuracy_score
# ----> 3 y_pred = model.predict(X_test)
#       4 balanced_accuracy_score(y_test, y_pred)
#
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/sklearn/linear_model/_base.py in predict(self, X)
#     423             Vector containing the class labels for each sample.
#     424         """
# --> 425         scores = self.decision_function(X)
#     426         if len(scores.shape) == 1:
#     427             indices = (scores > 0).astype(int)
#
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/sklearn/linear_model/_base.py in decision_function(self, X)
#     403             this class would be predicted.
#     404         """
# --> 405         check_is_fitted(self)
#     406
#     407         X = self._validate_data(X, accept_sparse="csr", reset=False)
#
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/sklearn/utils/validation.py in check_is_fitted(estimator, attributes, msg, all_or_any)
#    1220
#    1221     if not fitted:
# -> 1222         raise NotFittedError(msg % {"name": type(estimator).__name__})
#    1223
#    1224
#
# NotFittedError: This LogisticRegression instance is not fitted yet. Call 'fit' with appropriate arguments before using this estimator.

# %%
# Display the confusion matrix
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test, y_pred)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/0s/9pgh43n143n123rjw56tynrr0000gn/T/ipykernel_5435/1461509411.py in <module>
#       1 # Display the confusion matrix
#       2 from sklearn.metrics import confusion_matrix
# ----> 3 confusion_matrix(y_test, y_pred)
#
# NameError: name 'y_pred' is not defined

# %%
# Print the imbalanced classification report
# Naive Random Oversampling
from imblearn.metrics import classification_report_imbalanced
print(classification_report_imbalanced(y_test, y_pred))
# Out:
#                    pre       rec       spe        f1       geo       iba       sup
#
#   high_risk       0.01      0.74      0.55      0.02      0.64      0.42       101
#    low_risk       1.00      0.55      0.74      0.71      0.64      0.40     17104
#
# avg / total       0.99      0.55      0.74      0.71      0.64      0.40     17205

# %% [markdown]
# ### SMOTE Oversampling

# %%
# Resample the training data with SMOTE
from imblearn.over_sampling import SMOTE
X_resampled, y_resampled = SMOTE(random_state=1, sampling_strategy='auto').fit_resample(X_train, y_train)
Counter(y_resampled)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/0s/9pgh43n143n123rjw56tynrr0000gn/T/ipykernel_5435/1645750405.py in <module>
#       1 # Resample the training data with SMOTE
# ----> 2 from imblearn.over_sampling import SMOTE
#       3 X_resampled, y_resampled = SMOTE(random_state=1, sampling_strategy='auto').fit_resample(X_train, y_train)
#       4 Counter(y_resampled)
#
# ModuleNotFoundError: No module named 'imblearn'

# %%
# Train the Logistic Regression model using the resampled data
model = LogisticRegression(solver='lbfgs', random_state=1)
model.fit(X_resampled, y_resampled)
# Out:
# LogisticRegression(random_state=1)

# %%
# Calculated the balanced accuracy score
y_pred = model.predict(X_test)
balanced_accuracy_score(y_test, y_pred)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# /var/folders/0s/9pgh43n143n123rjw56tynrr0000gn/T/ipykernel_5435/1732006111.py in <module>
#       1 # Calculated the balanced accuracy score
# ----> 2 y_pred = model.predict(X_test)
#       3 balanced_accuracy_score(y_test, y_pred)
#
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/sklearn/linear_model/_base.py in predict(self, X)
#     423             Vector containing the class labels for each sample.
#     424         """
# --> 425         scores = self.decision_function(X)
#     426         if len(scores.shape) == 1:
#     427             indices = (scores > 0).astype(int)
#
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/sklearn/linear_model/_base.py in decision_function(self, X)
#     403             this class would be predicted.
#     404         """
# --> 405         check_is_fitted(self)
#     406
#     407         X = self._validate_data(X, accept_sparse="csr", reset=False)
#
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/sklearn/utils/validation.py in check_is_fitted(estimator, attributes, msg, all_or_any)
#    1220
#    1221     if not fitted:
# -> 1222         raise NotFittedError(msg % {"name": type(estimator).__name__})
#    1223
#    1224
#
# NotFittedError: This LogisticRegression instance is not fitted yet. Call 'fit' with appropriate arguments before using this estimator.

# %%
# Display the confusion matrix
confusion_matrix(y_test, y_pred)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/0s/9pgh43n143n123rjw56tynrr0000gn/T/ipykernel_5435/274704223.py in <module>
#       1 # Display the confusion matrix
# ----> 2 confusion_matrix(y_test, y_pred)
#
# NameError: name 'y_pred' is not defined

# %%
# Print the imbalanced classification report
# SMOTE Oversampling
print(classification_report_imbalanced(y_test, y_pred))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/0s/9pgh43n143n123rjw56tynrr0000gn/T/ipykernel_5435/3553522113.py in <module>
#       1 # Print the imbalanced classification report
#       2 # SMOTE Oversampling
# ----> 3 print(classification_report_imbalanced(y_test, y_pred))
#
# NameError: name 'classification_report_imbalanced' is not defined

# %% [markdown]
# # Undersampling
#
# In this section, you will test an undersampling algorithms to determine which algorithm results in the best performance compared to the oversampling algorithms above. You will undersample the data using the Cluster Centroids algorithm and complete the folliowing steps:
#
# 1. View the count of the target classes using `Counter` from the collections library.
# 3. Use the resampled data to train a logistic regression model.
# 3. Calculate the balanced accuracy score from sklearn.metrics.
# 4. Print the confusion matrix from sklearn.metrics.
# 5. Generate a classication report using the `imbalanced_classification_report` from imbalanced-learn.
#
# Note: Use a random state of 1 for each sampling algorithm to ensure consistency between tests

# %%
# Resample the data using the ClusterCentroids resampler
# Warning: This is a large dataset, and this step may take some time to complete
from imblearn.under_sampling import ClusterCentroids
cc = ClusterCentroids(random_state=1)
X_resampled, y_resampled = cc.fit_resample(X_train, y_train)
Counter(y_resampled)
# Out:
# Counter({'loan_status': 1})

# %%
# Train the Logistic Regression model using the resampled data
from sklearn.linear_model import LogisticRegression
model = LogisticRegression(solver='lbfgs', random_state=78)
model.fit(X_resampled, y_resampled)
# Out:
# LogisticRegression(random_state=1)

# %%
# Calculated the balanced accuracy score
from sklearn.metrics import balanced_accuracy_score
balanced_accuracy_score(y_test, y_pred)
# Out:
# 0.5442166848817717

# %%
# Display the confusion matrix
from sklearn.metrics import confusion_matrix
y_pred = model.predict(X_test)
confusion_matrix(y_test, y_pred)
# Out:
# array([[   68,    33],
#        [10003,  7101]])

# %%
# Print the imbalanced classification report
# YOUR CODE HERE
# Out:
#                    pre       rec       spe        f1       geo       iba       sup
#
#   high_risk       0.01      0.67      0.42      0.01      0.53      0.29       101
#    low_risk       1.00      0.42      0.67      0.59      0.53      0.27     17104
#
# avg / total       0.99      0.42      0.67      0.58      0.53      0.27     17205

# %% [markdown]
# # Combination (Over and Under) Sampling
#
# In this section, you will test a combination over- and under-sampling algorithm to determine if the algorithm results in the best performance compared to the other sampling algorithms above. You will resample the data using the SMOTEENN algorithm and complete the folliowing steps:
#
# 1. View the count of the target classes using `Counter` from the collections library.
# 3. Use the resampled data to train a logistic regression model.
# 3. Calculate the balanced accuracy score from sklearn.metrics.
# 4. Print the confusion matrix from sklearn.metrics.
# 5. Generate a classication report using the `imbalanced_classification_report` from imbalanced-learn.
#
# Note: Use a random state of 1 for each sampling algorithm to ensure consistency between tests

# %%
# Resample the training data with SMOTEENN
# Warning: This is a large dataset, and this step may take some time to complete
# YOUR CODE HERE
# Out:
# Counter({'loan_status': 1})

# %%
# Train the Logistic Regression model using the resampled data
# YOUR CODE HERE
# Out:
# LogisticRegression(random_state=1)

# %%
# Calculated the balanced accuracy score
# YOUR CODE HERE
# Out:
# 0.6400726134353378

# %%
# Display the confusion matrix
# YOUR CODE HERE
# Out:
# array([[  71,   30],
#        [7232, 9872]])

# %%
# Print the imbalanced classification report
# YOUR CODE HERE
# Out:
#                    pre       rec       spe        f1       geo       iba       sup
#
#   high_risk       0.01      0.70      0.58      0.02      0.64      0.41       101
#    low_risk       1.00      0.58      0.70      0.73      0.64      0.40     17104
#
# avg / total       0.99      0.58      0.70      0.73      0.64      0.40     17205
